# %% [markdown]
# # Data Science  vs Artificial Intelligence vs Machine Learning vs Deep Learning

# %% [markdown]
# I am sure that you may have exausted by looking at this type of venn diagram.

# %% [markdown]
# ![ml%201.jpg](attachment:ml%201.jpg)

# %% [markdown]
# I want to make this as simple as possible. Lets forget about whatever we know so far. I hope this file makes many Jargons and their applications clear.

# %% [markdown]
# I want ou all to just consider the following image. Just consider, I know this is one more venn diagram. I promise to simplify with the following image.
#
# ![ml2.jpg](attachment:ml2.jpg)

# %% [markdown]
# To start with, Artificial Intelligince and Data Science solve different set of problems each. Data Science(DS) and Artificial Intelligence(AI) both uses Machine Learning(ML) and Deep Learning(DL) to solve problems.

# %% [markdown]
# Data Science always deals with structured (numerical) data. The key problems we solve in Data science is Regression and Classification. Here we mostly predict values/classes for future.
#
# ### Example answers that Data Science can answer:
#
# Regression(predicts a number):
#
#     1. What could be the price of a certain stock based on its past performance?
#     2. What could be the profit of a company in next 5 years?
#     3. What could be the population of the country?
#
#
# Classification(predicting the class):
#
#     1. Will it rain today?
#     2. If a person is likely to get diabetics based on his current and past health parameters?
#     3. Will a customer prefers loan or not?

# %% [markdown]
# Artificial Intelligence(AI) uses ML and DL to solve mostly perception problems. And it works on unstructured data like images, videos, live video, audio clips, text and in solves perception problems. When I say perception I mean to look around the scene or text or listen and get an idea of the environment. And taking the next step according to the environment.

# %% [markdown]
# ### Example problems AI can solve:
#
#     1. All Computer Vision(CNN) applications like identifying number plates, Dog vs, cat and so on..
#     2. NLP to read and understand text like summarizing the article or sentiment analysis.
#     3. Google translate uses Computer vision first to capture the test, then NLP to process the text and then NLP again to
#     translate the text.
#     4. Alexa / Siri / google home will take the audio command, process it to understand the need, and take next Acton
#     accordingly.

# %%
## The Difference and similarities between AI and DS

import pandas as pd
data = {'Parameter':['Usage', 'Data Type', 'Solves', 'Analyses', 'Answers'],
        'Artificial intelligence':['ML and DL', 'Unstructured', 'Computer Vision, NLP, audio', 'Past and Present Data to see what happend and what happening', 'What happend and what is happening'],
        'Data Science':['ML and DL', 'Structured', 'Regression, Classification, Clusering', 'future value or class estimation', 'how much and which class']}
compare = pd.DataFrame(data)

compare
# Out:
#    Parameter                            Artificial intelligence  \
# 0      Usage                                          ML and DL
# 1  Data Type                                       Unstructured
# 2     Solves                        Computer Vision, NLP, audio
# 3   Analyses  Past and Present Data to see what happend and ...
# 4    Answers                 What happend and what is happening
#
#                             Data Science
# 0                              ML and DL
# 1                             Structured
# 2  Regression, Classification, Clusering
# 3       future value or class estimation
# 4               how much and which class

# %% [markdown]
# Note: The above comparison may have given you some clarity between AI and DS. Now I want to tell you one more tricky thing.
# We can not clearly draw a border between them.
#
# In few systems they both are used to solve little more complex problems like in Tesla Auto Pilot.

# %% [markdown]
# # Loss Funtion :
#
# Loss function is nothing but RMSE (Root Mean Square of Error), an error is defined as actual output vs predicted output. Then square all the error and find their mean. Take a root of the mean.
# Ideally the loss function should be as close to zero as possible.
#
#  on the other side, For any given data, the algorithm tries various functions (models), and selects that model which has least Loss function

# %% [markdown]
# # Evaluations:
#
# ### Accuracy:
#     no of correct prediction / total no of predictions
#
# ### Top K accuracy:
#
# ### Precesion:
#     no of times you took correct action / no of times the action was taken
#
#
# ### Recall:
#     of all the times you are supposed to take an action / how many times did you act
